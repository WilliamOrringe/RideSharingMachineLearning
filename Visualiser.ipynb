# %% [markdown]
# https://github.com/gboeing/osmnx

# %% [markdown]
# folium python

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
#Define coordinates of where we want to center our map
exeter_coords = [40.72, -73.9005]

#Create the map
my_map = folium.Map(location = exeter_coords, zoom_start = 12)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d80e2105b99f41c6af0a4ff29efa89c5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d80e2105b99f41c6af0a4ff29efa89c5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d80e2105b99f41c6af0a4ff29efa89c5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d80e2105b99f41c6af0a4ff29efa89c5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.72%2C%20-73.9005%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import osmnx as ox
import networkx as nx

import matplotlib.pyplot as plt

place_name = "Kamppi, Helsinki, Finland"
place_name = "Cardiff, Wales"
place_name = "Petersfield, Hampshire, England"
place_name = "Emersons Green, England"
graph = ox.graph_from_place(place_name, network_type="drive")
fig, ax = ox.plot_graph(graph, node_size=0, edge_linewidth=0.5, edge_color="r")
# Out:
# /opt/anaconda3/envs/ox/lib/python3.10/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
len(graph.nodes)
# Out:
# 762

# %% [markdown]
# SAVE FILE

# %%
ox.save_graphml(graph, filepath="./data/network.graphml")

# %% [markdown]
# ded

# %%
import osmnx as ox
import networkx as nx

import matplotlib.pyplot as plt

place_name = "New York City, New York, United States of America"

graph2 = ox.graph_from_place(place_name)

fig, ax = ox.plot_graph(graph2)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 10>()
#       6 place_name = "New York City, New York, United States of America"
#       8 graph2 = ox.graph_from_place(place_name)
# ---> 10 fig, ax = ox.plot_graph(graph2)
#      12 plt.tight_layout()
#
# File ~/opt/anaconda3/envs/ox/lib/python3.10/site-packages/osmnx/plot.py:212, in plot_graph(G, ax, figsize, bgcolor, node_color, node_size, node_alpha, node_edgecolor, node_zorder, edge_color, edge_linewidth, edge_alpha, show, close, save, filepath, dpi, bbox)
#     208     fig = ax.figure
#     210 if max_edge_lw > 0:
#     211     # plot the edges' geometries
# --> 212     gdf_edges = utils_graph.graph_to_gdfs(G, nodes=False)["geometry"]
#     213     ax = gdf_edges.plot(ax=ax, color=edge_color, lw=edge_linewidth, alpha=edge_alpha, zorder=1)
#     215 if max_node_size > 0:
#     216     # scatter plot the nodes' x/y coordinates
#
# File ~/opt/anaconda3/envs/ox/lib/python3.10/site-packages/osmnx/utils_graph.py:83, in graph_to_gdfs(G, nodes, edges, node_geometry, fill_edge_geometry)
#      80             return LineString((Point((x[u], y[u])), Point((x[v], y[v]))))
#      82     geom = map(make_geom, u, v, data)
# ---> 83     gdf_edges = gpd.GeoDataFrame(data, crs=crs, geometry=list(geom))
#      85 else:
#      86     gdf_edges = gpd.GeoDataFrame(data)
#
# File ~/opt/anaconda3/envs/ox/lib/python3.10/site-packages/osmnx/utils_graph.py:80, in graph_to_gdfs.<locals>.make_geom(u, v, data, x, y)
#      78     return data["geometry"]
#      79 else:
# ---> 80     return LineString((Point((x[u], y[u])), Point((x[v], y[v]))))
#
# File ~/opt/anaconda3/envs/ox/lib/python3.10/site-packages/shapely/geometry/point.py:51, in Point.__init__(self, *args)
#      49 if len(args) > 0:
#      50     if len(args) == 1:
# ---> 51         geom, n = geos_point_from_py(args[0])
#      52     elif len(args) > 3:
#      53         raise TypeError(
#      54             "Point() takes at most 3 arguments ({} given)".format(len(args))
#      55         )
#
# File ~/opt/anaconda3/envs/ox/lib/python3.10/site-packages/shapely/geometry/point.py:275, in geos_point_from_py(ob, update_geom, update_ndim)
#     271         raise ValueError(
#     272             "Wrong coordinate dimensions; this geometry has dimensions: "
#     273             "%d" % update_ndim)
#     274 else:
# --> 275     cs = lgeos.GEOSCoordSeq_create(1, n)
#     277 # Because of a bug in the GEOS C API, always set X before Y
#     278 lgeos.GEOSCoordSeq_setX(cs, 0, dx)
#
# KeyboardInterrupt:

# %%
len(graph2.nodes)

# %%
for i in graph2.nodes:
    print(graph2.nodes[i])
    break
print(graph2.nodes[30807314])
print(graph2.nodes[9560884166])

# %%
G2 = ox.add_edge_speeds(graph2)
G2 = ox.add_edge_travel_times(G2)

# %%
G2.__getitem__(30807314)

# %%
#nx.write_graphml(graph, 'graph.gml')
