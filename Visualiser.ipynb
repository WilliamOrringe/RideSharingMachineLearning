# %% [markdown]
# https://github.com/gboeing/osmnx

# %% [markdown]
# folium python

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
#Define coordinates of where we want to center our map
exeter_coords = [40.72, -73.9005]

#Create the map
my_map = folium.Map(location = exeter_coords, zoom_start = 12)

#Display the map
folium.Marker([-42,23]).add_to(map)
my_map

# %%
import osmnx as ox
import networkx as nx

import matplotlib.pyplot as plt

# place_name = "Kamppi, Helsinki, Finland"
# place_name = "Cardiff, Wales"
place_name = "Petersfield, Hampshire, England"
# place_name = "Emersons Green, England"
graph = ox.graph_from_place(place_name, network_type="drive")
fig, ax = ox.plot_graph(graph, node_size=0, edge_linewidth=0.5, edge_color="r")
# Out:
# /opt/anaconda3/envs/ox/lib/python3.10/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
len(graph.nodes)
# Out:
# 586

# %%
m = ox.plot_graph_folium(graph, popup_attribute='highway', weight=5, color='black')
m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# SAVE FILE

# %%
ox.save_graphml(graph, filepath="./data/network.graphml")

# %% [markdown]
# ded

# %%
import osmnx as ox
import networkx as nx

import matplotlib.pyplot as plt

place_name = "New York City, New York, United States of America"

graph2 = ox.graph_from_place(place_name)

fig, ax = ox.plot_graph(graph2)

plt.tight_layout()
# Out:
# /opt/anaconda3/envs/ox/lib/python3.10/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
len(graph2.nodes)
# Out:
# 225014

# %%
m = ox.plot_graph_folium(graph2, popup_attribute='highway', weight=5, color='black')
m

# %% [markdown]
# goat

# %%
for i in graph2.nodes:
    print(graph2.nodes[i])
    break
print(graph2.nodes[30807314])
print(graph2.nodes[9560884166])

# %%
G2 = ox.add_edge_speeds(graph2)
G2 = ox.add_edge_travel_times(G2)

# %%
G2.__getitem__(30807314)

# %%
#nx.write_graphml(graph, 'graph.gml')
